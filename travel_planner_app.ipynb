# %%
import streamlit as st
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, HumanMessage

# ✅ Securely Fetch API Key from Streamlit Secrets
GOOGLE_API_KEY = 'AIzaSyA3fhOqw-XuOQ3DwgSGzJqttcr-QOVHRbs'

# ✅ Function to fetch AI-generated travel options
def get_travel_options(source, destination):
    system_prompt = SystemMessage(
        content="You are an AI-powered travel assistant. Provide multiple travel options (cab, train, bus, flight) with estimated costs, duration, and relevant travel tips."
    )
    user_prompt = HumanMessage(
        content=f"I am traveling from {source} to {destination}. Suggest travel options with estimated cost, duration, and important details."
    )

    # ✅ Initialize AI model
    llm = ChatGoogleGenerativeAI(model="gemini-1.5-pro", google_api_key=GOOGLE_API_KEY)

    try:
        response = llm.invoke([system_prompt, user_prompt])
        return response.content if response else "⚠️ No response from AI."
    except Exception as e:
        return f"❌ Error fetching travel options: {str(e)}"

# ✅ Streamlit UI
st.title("🚀 AI-Powered Travel Planner")
st.markdown("Enter your travel details to get AI-generated travel options including cost estimates and travel tips.")

# ✅ User Inputs
source = st.text_input("🛫 Enter Source Location", placeholder="E.g., New York")
destination = st.text_input("🛬 Enter Destination", placeholder="E.g., Los Angeles")

if st.button("🔍 Find Travel Options"):
    if source.strip() and destination.strip():
        with st.spinner("🔄 Fetching best travel options..."):
            travel_info = get_travel_options(source, destination)
            st.success("✅ Travel Recommendations:")
            st.markdown(travel_info)
    else:
        st.warning("⚠️ Please enter both source and destination locations.")
# Out:
# 2025-02-27 05:33:10.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.744 Session state does not function when running a script without `streamlit run`
# 2025-02-27 05:33:10.745 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-27 05:33:10.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
from google.colab import drive
drive.mount('/content/drive')
